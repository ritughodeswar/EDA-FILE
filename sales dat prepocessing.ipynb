# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("C:\\Users\\DELL\\Downloads\\29. sales_data_final.csv")

# %%
data
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df= data.copy()

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.size
# Out:
# 1077090

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.describe(include='O')
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["order_id"].unique()
# Out:
# array(['AG-2011-2040', 'IN-2011-47883', 'HU-2011-1220', ...,
#        'MX-2014-108574', 'MO-2014-2560', 'CA-2014-156720'], dtype=object)

# %%
df["order_id"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object>

# %%
def uniquevals(col):
    print(f'Details of the paricular col {col} is : {df[col].unique()}')

def valuecounts(col):
    print(f'valuecounts of the particular col {col} is : {df[col].value_counts()}')

# %%
for i in df.columns:
    uniquevals(i)
    print()
    print("-"*30)
    print()
# Out:
# Details of the paricular col order_id is : ['AG-2011-2040' 'IN-2011-47883' 'HU-2011-1220' ... 'MX-2014-108574'
#  'MO-2014-2560' 'CA-2014-156720']
#
# ------------------------------
#
# Details of the paricular col order_date is : ['1/1/2011' '1/2/2011' '1/3/2011' ... '12/29/2014' '12/30/2014'
#  '12/31/2014']
#
# ------------------------------
#
# Details of the paricular col ship_date is : ['1/6/2011' '1/8/2011' '1/5/2011' ... '1/5/2015' '1/6/2015' '1/7/2015']
#
# ------------------------------
#
# Details of the paricular col ship_mode is : ['Standard Class' 'Second Class' 'Same Day' 'First Class']
#
# ------------------------------
#
# Details of the paricular col customer_name is : ['Toby Braunhardt' 'Joseph Holt' 'Annie Thurman' 'Eugene Moren'
#  'Magdelene Morse' 'Kean Nguyen' 'Ken Lonsdale' 'Lindsay Williams'
#  'Larry Blacks' 'Dorothy Dickinson' 'Dennis Pardue' 'Stewart Visinsky'
#  "Jas O'Carroll" 'Chris McAfee' 'Nat Gilpin' 'Jack Garza'
# ...

# %%
for i in df.columns:
    valuecounts(i)
    print()
    print("-"*40)
    print()
# Out:
# valuecounts of the particular col order_id is : order_id
# CA-2014-100111     14
# TO-2014-9950       13
# IN-2012-41261      13
# MX-2014-166541     13
# NI-2014-8880       13
#                    ..
# ES-2014-2815584     1
# IN-2014-78228       1
# MX-2014-122511      1
# OD-2014-9490        1
# ES-2011-4869686     1
# Name: count, Length: 25035, dtype: int64
#
# ----------------------------------------
#
# valuecounts of the particular col order_date is : order_date
# 6/18/2014     135
# 11/18/2014    127
# 9/3/2014      126
# 11/20/2014    118
# 12/29/2014    116
#              ...
# 8/19/2012       1
# 2/9/2014        1
# 2/27/2011       1
# 1/16/2011       1
# 1/2/2011        1
# Name: count, Length: 1430, dtype: int64
#
# ----------------------------------------
#
# valuecounts of the particular col ship_date is : ship_date
# 11/22/2014    130
# 9/7/2014      115
# 12/7/2014     101
# 11/17/2014    101
# 11/29/2014    100
#              ...
# 3/21/2013       3
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'] = df['order_id'].str.rep

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id']=df['order_id'].astype(int)

# %%
df['order_id'].dtypes
# Out:
# dtype('O')

# %%
df['sales'] = pd.to_numeric(df['sales'],
errors = 'coerce')

df['order_date']= pd.to_datetime(df['order_date'])

# %%
df['sales'].dtypes
# Out:
# dtype('float64')

# %%
df['order_date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
plt.figure(figsize=(4,4))
sns.distplot(df['sales'],color='blue')
# Out:
# <Axes: xlabel='sales', ylabel='Density'>

# %%
Description:- The distribution plot show that the data is (right skewed) positively skewed. most of the sales values lie between 0 and 200,
indicating that majority of order are low value.

# %%
plt.figure(figsize=(4,4))
sns.barplot(df['state'],color='red')
# Out:
# <Axes: ylabel='state'>

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date                 object
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %%
plt.figure(figsize=(4,4))
sns.barplot(df['state'],color='red')
plt.xticks(rotation=90)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000.]),
#  [Text(0.0, 0, '0'),
#   Text(10000.0, 0, '10000'),
#   Text(20000.0, 0, '20000'),
#   Text(30000.0, 0, '30000'),
#   Text(40000.0, 0, '40000'),
#   Text(50000.0, 0, '50000'),
#   Text(60000.0, 0, '60000')])

# %%
for col in toview
    drawplot(col)

# %%
def drawplot(df,col):
    plt.figure(figsize=(5,3))
    sns.countplot(data=df,x=col,pallate='plasma')
    plt.xticks(rotaion='vertical')

toview = ['sales','quantity','discount']

# %%
df.head()
# Out:
#           order_id order_date                                     ship_date  \
# 0       -2011-2040 2011-01-01  <function to_datetime at 0x000001EEBBEF9EE0>
# 1    IN-2011-47883 2011-01-01  <function to_datetime at 0x000001EEBBEF9EE0>
# 2     HU-2011-1220 2011-01-01  <function to_datetime at 0x000001EEBBEF9EE0>
# 3  IT-2011-3647632 2011-01-01  <function to_datetime at 0x000001EEBBEF9EE0>
# 4    IN-2011-47883 2011-01-01  <function to_datetime at 0x000001EEBBEF9EE0>
#
#         ship_mode    customer_name      segment            state    country  \
# 0  Standard Class  Toby Braunhardt     Consumer      Constantine    Algeria
# 1  Standard Class      Joseph Holt     Consumer  New South Wales  Australia
# 2    Second Class    Annie Thurman     Consumer         Budapest    Hungary
# 3    Second Class     Eugene Moren  Home Office        Stockholm     Sweden
# 4  Standard Class      Joseph Holt     Consumer  New South Wales  Australia
#
# ...

# %%
df.groupby('region')['sales'].sum().plot(kind='bar')
plt.show()

# %%
In this bar graph represented total sales across different regions.central region shows the highest sales,followed by south region.
